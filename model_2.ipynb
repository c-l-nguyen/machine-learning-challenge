# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /Users/utbootcamp/.conda/envs/PythonData/lib/python3.6/site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /Users/utbootcamp/.conda/envs/PythonData/lib/python3.6/site-packages (from sklearn) (0.22)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /Users/utbootcamp/.conda/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.16.4)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /Users/utbootcamp/.conda/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.3.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /Users/utbootcamp/.conda/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (0.13.2)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /Users/utbootcamp/.conda/envs/PythonData/lib/python3.6/site-packages (0.13.2)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("data/exoplanet_data.csv")

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[[
    'koi_fpflag_nt',
    'koi_fpflag_ss',
    'koi_fpflag_co',
    'koi_fpflag_ec',
    'koi_period',
    'koi_time0bk',
    'koi_impact',
    'koi_duration',
    'koi_depth',
    'koi_prad',
    'koi_teq',
    'koi_insol',
    'koi_model_snr',
    'koi_tce_plnt_num',
    'koi_steff',
    'koi_slogg',
    'koi_srad',
    'ra',
    'dec',
    'koi_kepmag'
]]

selected_features.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 0   162.513840       0.586       4.50700      874.8      2.83      443
# 1   175.850252       0.969       1.78220    10829.0     14.60      638
# 2   170.307565       1.276       2.40641     8079.2     33.46     1395
# 3   171.595550       0.701       1.65450      603.3      2.75     1406
# 4   172.979370       0.762       3.14020      686.0      2.77     1160
#
#    koi_insol  koi_model_snr  koi_tce_plnt_num  koi_steff  koi_slogg  koi_srad  \
# 0       9.11           25.8                 2       5455      4.467     0.927
# 1      39.30           76.3                 1       5853      4.544     0.868
# 2     891.96          505.6                 1       5805      4.564     0.791
# 3     926.16           40.9                 1       6031      4.438     1.046
# 4     427.65           40.2                 2       6046      4.486     0.972
#
#           ra        dec  koi_kepmag
# 0  291.93423  48.141651      15.347
# 1  297.00482  48.134129      15.436
# 2  285.53461  48.285210      15.597
# 3  288.75488  48.226200      15.509
# 4  296.28613  48.224670      15.714

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

X = selected_features
y = df['koi_disposition'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6971              1              0              0              0  373.893980
# 93                0              0              0              0   21.812960
# 4325              0              0              0              0  263.901410
# 5235              0              0              0              0  210.631486
# 1445              0              0              0              0    6.783413
#
#       koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 6971    261.49680      0.9630       27.6600      730.0      2.51      206
# 93      174.01085      0.0530        4.3791     1175.4      3.38      639
# 4325    203.17230      0.9585        4.3030      807.1     23.91      562
# 5235    300.72292      0.6420        8.4190     1657.8      3.23      234
# 1445    136.10468      0.6650        3.5437      501.2     20.75     2628
#
#       koi_insol  koi_model_snr  koi_tce_plnt_num  koi_steff  koi_slogg  \
# 6971       0.42           18.5                 3       5263      4.574
# 93        39.33           37.8                 1       5601      4.410
# 4325      23.60           11.0                 1       5094      3.126
# 5235       0.71           25.9                 1       4895      4.589
# 1445   11295.61           35.3                 1       5096      2.435
#
#       koi_srad         ra        dec  koi_kepmag
# 6971     0.699  290.93597  47.290730      14.911
# 93       0.999  294.77686  40.153740      15.540
# 4325     6.247  284.98364  41.881351      13.485
# 5235     0.759  287.30283  39.289688      15.195
# 1445     8.769  292.95416  41.934799      15.357

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=20)
rf = rf.fit(X_train, y_train)

print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.7392714094983788
# Testing Data Score: 0.7362700228832952

# %%
sorted(zip(rf.feature_importances_, selected_features.columns.values), reverse=True)
# Out:
# [(0.12820832230667317, 'koi_fpflag_nt'),
#  (0.11788500069613739, 'koi_fpflag_co'),
#  (0.10849114272299007, 'koi_model_snr'),
#  (0.08869293119979452, 'koi_prad'),
#  (0.08225281394261617, 'koi_fpflag_ss'),
#  (0.06530483814513406, 'koi_depth'),
#  (0.05208396062742835, 'koi_fpflag_ec'),
#  (0.04144533819962272, 'koi_insol'),
#  (0.040797289869549745, 'koi_impact'),
#  (0.03920873275788227, 'koi_period'),
#  (0.034790553875031965, 'koi_time0bk'),
#  (0.03230915999333537, 'koi_duration'),
#  (0.03171759646627452, 'koi_teq'),
#  (0.024451805731952263, 'koi_steff'),
#  (0.022149520619116913, 'dec'),
#  (0.021974706569901113, 'ra'),
#  (0.021779134914252738, 'koi_srad'),
#  (0.021000078867672054, 'koi_kepmag'),
#  (0.0186988669193709, 'koi_slogg'),
#  (0.006758205575263762, 'koi_tce_plnt_num')]

# %%
from sklearn.metrics import classification_report
print(classification_report(rf.predict(X_test), y_test))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.77      0.78      0.77       428
#      CONFIRMED       0.77      0.79      0.78       443
# FALSE POSITIVE       1.00      0.98      0.99       877
#
#       accuracy                           0.88      1748
#      macro avg       0.85      0.85      0.85      1748
#   weighted avg       0.89      0.88      0.88      1748

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators' : [10,20,50,100,200]}
grid = GridSearchCV(rf, param_grid, verbose = 3)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] n_estimators=10 .................................................
# [CV] ..................... n_estimators=10, score=0.890, total=   0.1s
# [CV] n_estimators=10 .................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] ..................... n_estimators=10, score=0.905, total=   0.1s
# [CV] n_estimators=10 .................................................
# [CV] ..................... n_estimators=10, score=0.894, total=   0.1s
# [CV] n_estimators=10 .................................................
# [CV] ..................... n_estimators=10, score=0.879, total=   0.1s
# [CV] n_estimators=10 .................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.4s remaining:    0.0s
# [CV] ..................... n_estimators=10, score=0.874, total=   0.1s
# [CV] n_estimators=20 .................................................
# [CV] ..................... n_estimators=20, score=0.896, total=   0.2s
# [CV] n_estimators=20 .................................................
# [CV] ..................... n_estimators=20, score=0.911, total=   0.2s
# [CV] n_estimators=20 .................................................
# [CV] ..................... n_estimators=20, score=0.902, total=   0.2s
# [CV] n_estimators=20 .................................................
# [CV] ..................... n_estimators=20, score=0.888, total=   0.2s
# [CV] n_estimators=20 .................................................
# [CV] ..................... n_estimators=20, score=0.884, total=   0.2s
# [CV] n_estimators=50 .................................................
# [CV] ..................... n_estimators=50, score=0.896, total=   0.4s
# [CV] n_estimators=50 .................................................
# [CV] ..................... n_estimators=50, score=0.910, total=   0.5s
# [CV] n_estimators=50 .................................................
# [CV] ..................... n_estimators=50, score=0.901, total=   0.5s
# [CV] n_estimators=50 .................................................
# [CV] ..................... n_estimators=50, score=0.897, total=   0.5s
# [CV] n_estimators=50 .................................................
# [CV] ..................... n_estimators=50, score=0.879, total=   0.5s
# [CV] n_estimators=100 ................................................
# [CV] .................... n_estimators=100, score=0.901, total=   1.0s
# [CV] n_estimators=100 ................................................
# [CV] .................... n_estimators=100, score=0.905, total=   1.0s
# [CV] n_estimators=100 ................................................
# [CV] .................... n_estimators=100, score=0.907, total=   0.9s
# [CV] n_estimators=100 ................................................
# [CV] .................... n_estimators=100, score=0.902, total=   0.9s
# [CV] n_estimators=100 ................................................
# [CV] .................... n_estimators=100, score=0.889, total=   0.9s
# [CV] n_estimators=200 ................................................
# [CV] .................... n_estimators=200, score=0.895, total=   2.1s
# [CV] n_estimators=200 ................................................
# [CV] .................... n_estimators=200, score=0.911, total=   1.9s
# [CV] n_estimators=200 ................................................
# [CV] .................... n_estimators=200, score=0.899, total=   2.0s
# [CV] n_estimators=200 ................................................
# [CV] .................... n_estimators=200, score=0.904, total=   2.0s
# [CV] n_estimators=200 ................................................
# [CV] .................... n_estimators=200, score=0.890, total=   1.9s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   18.4s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=20, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_estimators': [10, 20, 50, 100, 200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=4)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'n_estimators': 100}
# 0.900627460540391

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'chris_nguyen_model_2.sav'
joblib.dump(rf, filename)
# Out:
# ['chris_nguyen_model_2.sav']
